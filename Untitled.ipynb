# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
import re
import seaborn as sns

# %%
df=pd.read_csv("medical_records.csv")

# %%
df
# Out:
#       age        anaemia  creatinine_phosphokinase      diabetes  \
# 0    55.0  non-anaemitic                       748  non-diabetic
# 1    60.0      anaemitic                        95  non-diabetic
# 2    50.0      anaemitic                       121      diabetic
# 3    59.0      anaemitic                       176      diabetic
# 4    45.0  non-anaemitic                       292      diabetic
# ..    ...            ...                       ...           ...
# 341  86.0  non-anaemitic                       582  non-diabetic
# 342  44.0  non-anaemitic                       582      diabetic
# 343  42.0  non-anaemitic                      5209  non-diabetic
# 344  60.0  non-anaemitic                       235      diabetic
# 345  85.0  non-anaemitic                      5882  non-diabetic
#
#      ejection_fraction high_blood_pressure  platelets  serum_creatinine  \
# 0                   45         not-present  263000.00              1.30
# ...

# %%
test = df[df['DEATH_EVENT'].isnull()]

# %%
test
# Out:
#       age        anaemia  creatinine_phosphokinase      diabetes  \
# 4    45.0  non-anaemitic                       292      diabetic
# 9    45.0  non-anaemitic                       582  non-diabetic
# 10   60.0      anaemitic                        47  non-diabetic
# 11   51.0  non-anaemitic                      1380  non-diabetic
# 18   75.0  non-anaemitic                       582      diabetic
# 25   70.0  non-anaemitic                       571      diabetic
# 27   50.0      anaemitic                       115  non-diabetic
# 28   55.0  non-anaemitic                       582      diabetic
# 36   55.0  non-anaemitic                        60  non-diabetic
# 64   40.0  non-anaemitic                       624  non-diabetic
# 74   70.0  non-anaemitic                       212      diabetic
# 75   50.0      anaemitic                       298  non-diabetic
# 79   60.0      anaemitic                       607  non-diabetic
# ...

# %%
test.to_csv('Test.csv',index=False)

# %%
df = df.dropna(how='any',axis=0)

# %%
df
# Out:
#       age        anaemia  creatinine_phosphokinase      diabetes  \
# 0    55.0  non-anaemitic                       748  non-diabetic
# 1    60.0      anaemitic                        95  non-diabetic
# 2    50.0      anaemitic                       121      diabetic
# 3    59.0      anaemitic                       176      diabetic
# 5    79.0      anaemitic                        55  non-diabetic
# ..    ...            ...                       ...           ...
# 341  86.0  non-anaemitic                       582  non-diabetic
# 342  44.0  non-anaemitic                       582      diabetic
# 343  42.0  non-anaemitic                      5209  non-diabetic
# 344  60.0  non-anaemitic                       235      diabetic
# 345  85.0  non-anaemitic                      5882  non-diabetic
#
#      ejection_fraction high_blood_pressure  platelets  serum_creatinine  \
# 0                   45         not-present  263000.00              1.30
# ...

# %%
df.dtypes
# Out:
# age                         float64
# anaemia                      object
# creatinine_phosphokinase      int64
# diabetes                     object
# ejection_fraction             int64
# high_blood_pressure          object
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                          object
# smoking                      object
# time                          int64
# patient_id                    int64
# DEATH_EVENT                 float64
# dtype: object

# %%
df.shape
# Out:
# (286, 14)

# %%
df.describe()
# Out:
#               age  creatinine_phosphokinase  ejection_fraction      platelets  \
# count  286.000000                286.000000         286.000000     286.000000
# mean    60.691147                602.164336          37.818182  261902.918497
# std     12.162664                951.966152          11.231307   95020.712832
# min     40.000000                 23.000000          15.000000   47000.000000
# 25%     50.000000                121.000000          30.000000  211000.000000
# 50%     60.000000                250.000000          38.000000  262500.000000
# 75%     69.000000                582.000000          43.750000  305000.000000
# max     95.000000               7861.000000          80.000000  742000.000000
#
#        serum_creatinine  serum_sodium        time    patient_id  DEATH_EVENT
# count        286.000000    286.000000  286.000000    286.000000   286.000000
# mean           1.359441    136.405594  131.398601  10150.552448     0.293706
# ...

# %%
# list of numerical variables
numerical_features = [feature for feature in df.columns if df[feature].dtypes != 'O']

# %%
print('Number of numerical variables: ', len(numerical_features))

# visualise the numerical variables
df[numerical_features].head()
# Out:
# Number of numerical variables:  9
#     age  creatinine_phosphokinase  ejection_fraction  platelets  \
# 0  55.0                       748                 45   263000.0
# 1  60.0                        95                 60   337000.0
# 2  50.0                       121                 40   260000.0
# 3  59.0                       176                 25   221000.0
# 5  79.0                        55                 50   172000.0
#
#    serum_creatinine  serum_sodium  time  patient_id  DEATH_EVENT
# 0               1.3           137    88       10106          0.0
# 1               1.0           138   146       10175          0.0
# 2               0.7           130   175       10192          0.0
# 3               1.0           136   150       10181          1.0
# 5               1.8           133    78       10083          0.0

# %%
## Numerical variables are usually of 2 type
## 1. Continous variable and Discrete Variables

discrete_feature=[feature for feature in numerical_features if len(df[feature].unique())<25 and feature not in ['year']+['Id']]
print("Discrete Variables Count: {}".format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 2

# %%
continuous_feature=[feature for feature in numerical_features if feature not in discrete_feature]
print("Continuous feature Count {}".format(len(continuous_feature)))
# Out:
# Continuous feature Count 7

# %%
discrete_feature
# Out:
# ['ejection_fraction', 'DEATH_EVENT']

# %%
x = df['DEATH_EVENT'].value_counts()
x.tolist()
pop = ['1','0']
piechart = plt.pie(x,  labels = pop, autopct = '%1.1f%%')
plt.title('Death_Events', fontsize = 15, fontweight = 'bold')
plt.axis('equal')
fig = plt.gcf()
fig.set_size_inches(6,6) # or (4,4) or (5,5) or whatever
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-f508fccf2bd8> in <module>
#       2 x.tolist()
#       3 pop = ['1','0']
# ----> 4 piechart = plt.pie(x,  labels = pop, autopct = '%1.1f%%')
#       5 plt.title('Death_Events', fontsize = 15, fontweight = 'bold')
#       6 plt.axis('equal')
#
# AttributeError: module 'matplotlib' has no attribute 'pie'

# %%
facet = sns.FacetGrid(df, hue="DEATH_EVENT",aspect=1,size=5)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(df['age'].min(), df['age'].max()))
facet.add_legend()
# Out:
# C:\Users\Parul\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
facet = sns.FacetGrid(df, hue="DEATH_EVENT",aspect=1,size=5)
facet.map(sns.kdeplot,'creatinine_phosphokinase',shade= True)
facet.set(xlim=(df['creatinine_phosphokinase'].min(), df['creatinine_phosphokinase'].max()))
facet.add_legend()
# Out:
# C:\Users\Parul\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
facet = sns.FacetGrid(df, hue="DEATH_EVENT",aspect=1,size=5)
facet.map(sns.kdeplot,'ejection_fraction',shade= True)
facet.set(xlim=(df['ejection_fraction'].min(), df['ejection_fraction'].max()))
facet.add_legend()
# Out:
# C:\Users\Parul\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
facet = sns.FacetGrid(df, hue="DEATH_EVENT",aspect=1,size=5)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(df['age'].min(), df['age'].max()))
facet.add_legend()

# %%
facet = sns.FacetGrid(df, hue="DEATH_EVENT",aspect=1,size=5)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(df['age'].min(), df['age'].max()))
facet.add_legend()

# %%
facet = sns.FacetGrid(df, hue="DEATH_EVENT",aspect=1,size=5)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(df['age'].min(), df['age'].max()))
facet.add_legend()

# %%
facet = sns.FacetGrid(df, hue="DEATH_EVENT",aspect=1,size=5)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(df['age'].min(), df['age'].max()))
facet.add_legend()

# %%
facet = sns.FacetGrid(df, hue="DEATH_EVENT",aspect=1,size=5)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(df['age'].min(), df['age'].max()))
facet.add_legend()

# %%
sns.pairplot(df, hue='DEATH_EVENT')

# %%
categorical_features=['anaemia', 'diabetes', 'high_blood_pressure', 'smoking', 'sex']

# %%
sns.countplot('anaemia', data=df, hue='DEATH_EVENT')

# %%
sns.countplot('diabetes', data=df, hue='DEATH_EVENT')

# %%
sns.countplot('high_blood_pressure', data=df, hue='DEATH_EVENT')

# %%
sns.countplot('sex', data=df, hue='DEATH_EVENT')

# %%
sns.countplot('smoking', data=df, hue='DEATH_EVENT')

# %%
def category_onehot_multcols(multcolumns):
    df_final=df
    i=0
    for fields in multcolumns:
        
        print(fields)
        df1=pd.get_dummies(df[fields],drop_first=True)
        
        df.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df1.copy()
        else:
            
            df_final=pd.concat([df_final,df1],axis=1)
        i=i+1
       
        
    df_final=pd.concat([df,df_final],axis=1)
        
    return df_final

# %%
df=category_onehot_multcols(categorical_features)
# Out:
# anaemia
# diabetes
# high_blood_pressure
# smoking
# sex
# C:\Users\Parul\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df
# Out:
#       age  creatinine_phosphokinase  ejection_fraction  platelets  \
# 0    55.0                       748                 45  263000.00
# 1    60.0                        95                 60  337000.00
# 2    50.0                       121                 40  260000.00
# 3    59.0                       176                 25  221000.00
# 5    79.0                        55                 50  172000.00
# ..    ...                       ...                ...        ...
# 341  86.0                       582                 38  263358.03
# 342  44.0                       582                 30  263358.03
# 343  42.0                      5209                 30  226000.00
# 344  60.0                       235                 38  329000.00
# 345  85.0                      5882                 35  243000.00
#
#      serum_creatinine  serum_sodium  time  patient_id  DEATH_EVENT  \
# 0                1.30           137    88       10106          0.0
# ...

# %%
df.to_csv('final_train.csv',index=False)

# %%
from sklearn.model_selection import train_test_split
# train - 70
# test - 30
X = df.drop(columns=['DEATH_EVENT','patient_id'])
Y = df['DEATH_EVENT']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import GradientBoostingClassifier

# %%
lr_list = [0.05, 0.075, 0.1, 0.25, 0.5, 0.75, 1]

for learning_rate in lr_list:
    gb_clf = GradientBoostingClassifier(n_estimators=20, learning_rate=learning_rate, max_features=2, max_depth=2, random_state=0)
    gb_clf.fit(x_train, y_train)

    print("Learning rate: ", learning_rate)
    print("Accuracy score (training): {0:.3f}".format(gb_clf.score(x_train, y_train)))
    print("Accuracy score (validation): {0:.3f}".format(gb_clf.score(x_test, y_test)))
# Out:
# Learning rate:  0.05
# Accuracy score (training): 0.800
# Accuracy score (validation): 0.744
# Learning rate:  0.075
# Accuracy score (training): 0.850
# Accuracy score (validation): 0.802
# Learning rate:  0.1
# Accuracy score (training): 0.865
# Accuracy score (validation): 0.814
# Learning rate:  0.25
# Accuracy score (training): 0.930
# Accuracy score (validation): 0.942
# Learning rate:  0.5
# Accuracy score (training): 0.950
# Accuracy score (validation): 0.942
# Learning rate:  0.75
# Accuracy score (training): 0.980
# Accuracy score (validation): 0.942
# Learning rate:  1
# Accuracy score (training): 0.980
# Accuracy score (validation): 0.953

# %%
from xgboost import XGBClassifier

# %%
xgb_clf=XGBClassifier(silent=False, 
                      eta= 0.3,
                      scale_pos_weight=1,
                      learning_rate=0.01,  
                      colsample_bytree = 0.8,
                      subsample = 1,
                      objective='multi:softprob', 
                      n_estimators=80, 
                      reg_alpha = 0.3,
                      max_depth=8, 
                      gamma=0)
#xgb_clf = XGBClassifier()

# %%
xgb_clf.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-97-3fa8227421a3> in <module>
# ----> 1 xgb_clf.fit(x_train, y_train)
#
# ~\anaconda3\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     730                               evals_result=evals_result, obj=obj, feval=feval,
#     731                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 732                               callbacks=callbacks)
#     733
#     734         self.objective = xgb_options["objective"]
#
# ~\anaconda3\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
# ...
